# %%
import pandas as  pd
import numpy as np

# %%
df = pd.read_csv('/Users/aditya/Desktop/Pandas/anime.csv')

# %%
df.loc[2]['Title']
# Out:
# 'Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 - Dec 2022474,138 members'
